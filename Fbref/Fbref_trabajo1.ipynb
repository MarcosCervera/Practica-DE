# %%
import LanusStats as ls  
fbref = ls.Fbref()

# %%
equipos_stats=fbref.get_teams_season_stats('stats', 'Copa de la Liga', season='2024', save_csv=False, stats_vs=False, change_columns_names=False, add_page_name=False)
# Out:
# Starting to scrape teams data from Fbref...

# %%
equipos_stats
# Out:
#                       Squad  # Pl   Age  Poss  MP  Starts   Min   90s  Gls  \
# 0               Arg Juniors    26  25.3  52.4  14     154  1260  14.0   25
# 1              Atlé Tucumán    24  26.7  50.6  14     154  1260  14.0    8
# 2                  Banfield    27  28.3  44.4  14     154  1260  14.0   14
# 3          Barracas Central    24  25.9  44.9  14     154  1260  14.0   19
# 4                  Belgrano    33  26.6  49.3  14     154  1260  14.0   19
# 5              Boca Juniors    29  28.4  54.5  14     154  1260  14.0   19
# 6          Cen. Córdoba–SdE    31  26.3  47.0  14     154  1260  14.0   10
# 7            Defensa y Just    30  26.8  51.1  14     154  1260  14.0   17
# 8         Deportivo Riestra    30  30.7  35.6  14     154  1260  14.0    8
# 9               Estudiantes    29  28.3  55.8  14     154  1260  14.0   19
# 10              Gimnasia–LP    26  27.9  47.7  14     154  1260  14.0   17
# ...
